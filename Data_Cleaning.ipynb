# %% [markdown]
# ## Supermarket sales analysis

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('SuperMarket Analysis.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Time'] = pd.to_datetime(df['Time'], format='%I:%M:%S %p').dt.time

# %%
df['Month'] = df['Date'].dt.strftime('%B')
df['Day_Name'] = df['Date'].dt.strftime('%A')
df['Is_Weekend'] = df['Day_Name'].isin(['Saturday', 'Sunday']).astype(int)

# %%
def get_time_slot(time_obj):
    hour = time_obj.hour
    if hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    else:
        return 'Evening'

df['Time_Slot'] = df['Time'].apply(get_time_slot)

# %%
df.to_csv('Cleaned_SuperMarket_Sales.csv', index=False)
print("Data Cleaned and Saved Successfully!")
# Out:
# Data Cleaned and Saved Successfully!

# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv("Cleaned_SuperMarket_Sales.csv")

# %%
df.columns = df.columns.str.replace(' ', '_').str.replace('%', 'percent')

# %%
conn = sqlite3.connect("D:/Data Analysis/supermarket.db")

# %%
df.to_sql("supermarket_sales", conn, if_exists="replace", index=False)
conn.close()

# %%
print("Success: Data loaded into SQL database with correct column names!")
# Out:
# Success: Data loaded into SQL database with correct column names!
